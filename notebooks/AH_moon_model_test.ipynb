# %% [markdown]
# ## Imports

# %%
import numpy as np 
import pandas as pd 
import sqlite3
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Linear Regression Test

# %%
conn = sqlite3.connect('../datasets/database.db')
c = conn.cursor()

# %%
c.execute("SELECT * FROM moons_table")
rows = c.fetchall()
rows
# Out:
# [(0, 356),
#  (1, 713),
#  (2, 1071),
#  (3, 1428),
#  (4, 1785),
#  (5, 2142),
#  (6, 2498),
#  (7, 2853),
#  (8, 3209),
#  (9, 3563),
#  (10, 3917),
#  (11, 4270),
#  (12, 4622),
#  (13, 4974),
#  (14, 5326),
#  (15, 5678),
#  (16, 6030),
#  (17, 6382),
#  (18, 6734),
#  (19, 7087),
#  (20, 7440),
#  (21, 7794),
#  (22, 8148),
#  (23, 8502),
#  (24, 8857),
#  (25, 9213),
#  (26, 9568),
#  (27, 9925),
#  (28, 10281),
#  (29, 10638),
#  (30, 10994),
#  (31, 11351),
#  (32, 11707),
#  (33, 12063),
#  (34, 12419),
#  (35, 12774),
#  (36, 13128),
#  (37, 13482),
#  (38, 13836),
#  (39, 14188),
#  (40, 14541),
#  (41, 14894),
#  (42, 15247),
#  (43, 15599),
#  (44, 15952),
#  (45, 16305),
#  (46, 16658),
#  (47, 17012),
#  (48, 17365),
#  (49, 17719),
#  (50, 18073),
#  (51, 18428),
#  (52, 18782),
#  (53, 19137),
#  (54, 19492),
#  (55, 19848),
#  (56, 20204),
#  (57, 20560),
#  (58, 20916),
#  (59, 21272),
#  (60, 21627),
#  (61, 21983),
#  (62, 22338),
#  (63, 22692),
#  (64, 23047),
# ...

# %%
model = LinearRegression()

X = data[['GrLivArea']]
y = data['SalePrice']

# Train the model on the data
model.fit(X, y)
